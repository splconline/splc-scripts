# %%
import pandas as pd
from pathlib import Path
input_file = Path.cwd()/'room_details.csv'
df = pd.read_csv(input_file)

# %%
df.columns=[c.lower() for c in df.columns]

# %%
df.drop(['charge_type','discount','additional_charges'], axis=1, inplace=True)

# %%
df.head()
# Out:
#       room       day         date      time duration total_charges
# 0   Room 2  Saturday  30-Apr-2022  12:30:00     1:30        $30.00
# 1   Room 1  Saturday  30-Apr-2022  13:00:00     3:00        $60.00
# 2   Room 2  Saturday  30-Apr-2022  14:00:00     2:00        $40.00
# 3   Room 4  Saturday  30-Apr-2022  14:00:00     2:00        $40.00
# 4   Room 3  Saturday  30-Apr-2022  14:00:00     2:00        $40.00

# %%
pd.set_option('display.max_rows', 100)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   room           76 non-null     object
#  1   day            76 non-null     object
#  2   date           76 non-null     datetime64[ns]
#  3   time           76 non-null     object
#  4   duration       76 non-null     object
#  5   total_charges  76 non-null     object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 3.7+ KB

# %%
df.head()
# Out:
#       room       day       date      time duration total_charges
# 0   Room 2  Saturday 2022-04-30  12:30:00     1:30        $30.00
# 1   Room 1  Saturday 2022-04-30  13:00:00     3:00        $60.00
# 2   Room 2  Saturday 2022-04-30  14:00:00     2:00        $40.00
# 3   Room 4  Saturday 2022-04-30  14:00:00     2:00        $40.00
# 4   Room 3  Saturday 2022-04-30  14:00:00     2:00        $40.00

# %%
df = df.sort_values(['day','room','time'])

# %%
df
# Out:
#             room        day       date      time duration total_charges
# 6         Room 2     Monday 2022-05-02  19:00:00     2:00        $40.00
# 16        Room 2     Monday 2022-05-09  19:00:00     2:00        $40.00
# 24        Room 2     Monday 2022-05-16  19:00:00     2:00        $40.00
# 34        Room 2     Monday 2022-05-23  19:00:00     2:00        $40.00
# 40        Room 2     Monday 2022-05-30  19:00:00     2:00        $40.00
# 49        Room 2     Monday 2022-06-13  19:00:00     2:00        $40.00
# 57        Room 2     Monday 2022-06-20  19:00:00     2:00        $40.00
# 68        Room 2     Monday 2022-06-27  19:00:00     2:00        $40.00
# 5         Room 3     Monday 2022-05-02  19:00:00     2:00        $40.00
# 15        Room 3     Monday 2022-05-09  19:00:00     2:00        $40.00
# 25        Room 3     Monday 2022-05-16  19:00:00     2:00        $40.00
# 33        Room 3     Monday 2022-05-23  19:00:00     2:00        $40.00
# 39        Room 3     Monday 2022-05-30  19:00:00     2:00        $40.00
# 48        Room 3     Monday 2022-06-13  19:00:00     2:00        $40.00
# 58        Room 3     Monday 2022-06-20  19:00:00     2:00        $40.00
# 67        Room 3     Monday 2022-06-27  19:00:00     2:00        $40.00
# 66  Kitchen Demo     Monday 2022-06-27  18:30:00     0:30        $10.00
# 1         Room 1   Saturday 2022-04-30  13:00:00     3:00        $60.00
# 11        Room 1   Saturday 2022-05-07  13:00:00     3:00        $60.00
# 21        Room 1   Saturday 2022-05-14  13:00:00     3:00        $60.00
# 29        Room 1   Saturday 2022-05-21  13:00:00     3:00        $60.00
# 36        Room 1   Saturday 2022-05-28  13:00:00     3:00        $60.00
# 44        Room 1   Saturday 2022-06-11  13:00:00     3:00        $60.00
# 53        Room 1   Saturday 2022-06-18  13:00:00     3:00        $60.00
# 62        Room 1   Saturday 2022-06-25  13:00:00     3:00        $60.00
# 0         Room 2   Saturday 2022-04-30  12:30:00     1:30        $30.00
# 2         Room 2   Saturday 2022-04-30  14:00:00     2:00        $40.00
# 10        Room 2   Saturday 2022-05-07  12:30:00     1:30        $30.00
# 14        Room 2   Saturday 2022-05-07  14:00:00     2:00        $40.00
# 20        Room 2   Saturday 2022-05-14  12:30:00     1:30        $30.00
# 23        Room 2   Saturday 2022-05-14  14:00:00     2:00        $40.00
# 30        Room 2   Saturday 2022-05-21  14:00:00     2:00        $40.00
# 46        Room 2   Saturday 2022-06-11  14:00:00     2:00        $40.00
# 55        Room 2   Saturday 2022-06-18  14:00:00     2:00        $40.00
# 63        Room 2   Saturday 2022-06-25  14:00:00     2:00        $40.00
# 73        Room 2   Saturday 2022-07-02  14:00:00     2:00        $40.00
# 4         Room 3   Saturday 2022-04-30  14:00:00     2:00        $40.00
# 13        Room 3   Saturday 2022-05-07  14:00:00     2:00        $40.00
# 22        Room 3   Saturday 2022-05-14  14:00:00     2:00        $40.00
# 32        Room 3   Saturday 2022-05-21  14:00:00     2:00        $40.00
# 38        Room 3   Saturday 2022-05-28  14:00:00     2:00        $40.00
# 47        Room 3   Saturday 2022-06-11  14:00:00     2:00        $40.00
# 54        Room 3   Saturday 2022-06-18  14:00:00     2:00        $40.00
# 64        Room 3   Saturday 2022-06-25  14:00:00     2:00        $40.00
# 3         Room 4   Saturday 2022-04-30  14:00:00     2:00        $40.00
# 12        Room 4   Saturday 2022-05-07  14:00:00     2:00        $40.00
# 31        Room 4   Saturday 2022-05-21  14:00:00     2:00        $40.00
# 37        Room 4   Saturday 2022-05-28  14:00:00     2:00        $40.00
# 45        Room 4   Saturday 2022-06-11  14:00:00     2:00        $40.00
# 56        Room 4   Saturday 2022-06-18  14:00:00     2:00        $40.00
# 65        Room 4   Saturday 2022-06-25  14:00:00     2:00        $40.00
# 72        Room 4   Saturday 2022-07-02  14:00:00     2:00        $40.00
# 9         Room 3   Thursday 2022-05-05  17:30:00     2:00        $40.00
# 19        Room 3   Thursday 2022-05-12  17:45:00     2:00        $40.00
# 28        Room 3   Thursday 2022-05-19  17:45:00     2:00        $40.00
# 42        Room 3   Thursday 2022-06-02  17:45:00     2:00        $40.00
# 52        Room 3   Thursday 2022-06-16  17:45:00     2:00        $40.00
# 61        Room 3   Thursday 2022-06-23  17:45:00     2:00        $40.00
# 71        Room 3   Thursday 2022-06-30  17:45:00     2:00        $40.00
# 75        Room 3   Thursday 2022-07-07  17:45:00     2:00        $40.00
# 8         Room 2  Wednesday 2022-05-04  18:00:00     1:30        $30.00
# 18        Room 2  Wednesday 2022-05-11  18:00:00     1:30        $30.00
# 27        Room 2  Wednesday 2022-05-18  18:00:00     1:30        $30.00
# 43        Room 2  Wednesday 2022-06-08  18:00:00     2:00        $40.00
# 51        Room 2  Wednesday 2022-06-15  18:00:00     2:00        $40.00
# 60        Room 2  Wednesday 2022-06-22  18:00:00     2:00        $40.00
# 70        Room 2  Wednesday 2022-06-29  18:00:00     2:00        $40.00
# 74        Room 2  Wednesday 2022-07-06  18:00:00     1:00        $20.00
# 7         Room 3  Wednesday 2022-05-04  17:30:00     2:00        $40.00
# 17        Room 3  Wednesday 2022-05-11  17:30:00     2:00        $40.00
# 26        Room 3  Wednesday 2022-05-18  17:30:00     2:00        $40.00
# 35        Room 3  Wednesday 2022-05-25  17:30:00     2:00        $40.00
# 41        Room 3  Wednesday 2022-06-01  17:30:00     2:00        $40.00
# 50        Room 3  Wednesday 2022-06-15  17:30:00     2:00        $40.00
# 59        Room 3  Wednesday 2022-06-22  17:30:00     2:00        $40.00
# 69        Room 3  Wednesday 2022-06-29  17:30:00     2:00        $40.00

# %%
df.to_csv('hurrah.csv',index=False)
