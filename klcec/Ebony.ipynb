# %%
import pandas as pd
from pathlib import Path
input_file = Path.cwd()/'room_details.csv'
df = pd.read_csv(input_file)

# %%
df.columns=[c.lower() for c in df.columns]

# %%
df.drop(['charge_type','discount','additional_charges'], axis=1, inplace=True)

# %%
df.head()
# Out:
#       room        day         date      time duration total_charges
# 0   Room 2     Monday  12-Jul-2021  19:00:00     2:00        $40.00
# 1   Room 2  Wednesday  14-Jul-2021  17:30:00     2:00        $40.00
# 2   Room 1     Friday  16-Jul-2021  17:30:00     1:30        $30.00
# 3   Room 2     Monday  19-Jul-2021  19:00:00     2:00        $40.00
# 4   Room 2  Wednesday  21-Jul-2021  17:30:00     2:00        $40.00

# %%
pd.set_option('display.max_rows', 100)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   room           68 non-null     object
#  1   day            68 non-null     object
#  2   date           68 non-null     datetime64[ns]
#  3   time           68 non-null     object
#  4   duration       68 non-null     object
#  5   total_charges  68 non-null     object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 3.3+ KB

# %%
df.head()
# Out:
#       room        day       date      time duration total_charges
# 0   Room 2     Monday 2021-07-12  19:00:00     2:00        $40.00
# 1   Room 2  Wednesday 2021-07-14  17:30:00     2:00        $40.00
# 2   Room 1     Friday 2021-07-16  17:30:00     1:30        $30.00
# 3   Room 2     Monday 2021-07-19  19:00:00     2:00        $40.00
# 4   Room 2  Wednesday 2021-07-21  17:30:00     2:00        $40.00

# %%
df = df.sort_values(['day','room','time'])

# %%
df
# Out:
#        room        day       date      time duration total_charges
# 2    Room 1     Friday 2021-07-16  17:30:00     1:30        $30.00
# 5    Room 1     Friday 2021-07-23  17:30:00     1:30        $30.00
# 0    Room 2     Monday 2021-07-12  19:00:00     2:00        $40.00
# 3    Room 2     Monday 2021-07-19  19:00:00     2:00        $40.00
# 6    Room 2     Monday 2021-08-02  19:00:00     2:00        $40.00
# 13   Room 2     Monday 2021-08-09  19:00:00     2:00        $40.00
# 28   Room 2     Monday 2021-08-23  19:00:00     2:00        $40.00
# 36   Room 2     Monday 2021-08-30  19:00:00     2:00        $40.00
# 44   Room 2     Monday 2021-09-06  19:00:00     2:00        $40.00
# 52   Room 2     Monday 2021-09-13  19:00:00     2:00        $40.00
# 10   Room 1   Saturday 2021-08-07  13:00:00     3:00        $60.00
# 18   Room 1   Saturday 2021-08-14  13:00:00     3:00        $60.00
# 25   Room 1   Saturday 2021-08-21  13:00:00     3:00        $60.00
# 33   Room 1   Saturday 2021-08-28  13:00:00     3:00        $60.00
# 41   Room 1   Saturday 2021-09-04  13:00:00     3:00        $60.00
# 49   Room 1   Saturday 2021-09-11  13:00:00     3:00        $60.00
# 57   Room 1   Saturday 2021-09-18  13:00:00     3:00        $60.00
# 64   Room 1   Saturday 2021-09-25  13:00:00     3:00        $60.00
# 9    Room 2   Saturday 2021-08-07  12:30:00     1:30        $30.00
# 17   Room 2   Saturday 2021-08-14  12:30:00     1:30        $30.00
# 24   Room 2   Saturday 2021-08-21  12:30:00     1:30        $30.00
# 32   Room 2   Saturday 2021-08-28  12:30:00     1:30        $30.00
# 40   Room 2   Saturday 2021-09-04  12:30:00     1:30        $30.00
# 48   Room 2   Saturday 2021-09-11  12:30:00     1:30        $30.00
# 56   Room 2   Saturday 2021-09-18  12:30:00     1:30        $30.00
# 63   Room 2   Saturday 2021-09-25  12:30:00     1:30        $30.00
# 12   Room 2   Saturday 2021-08-07  14:00:00     2:00        $40.00
# 20   Room 2   Saturday 2021-08-14  14:00:00     2:00        $40.00
# 27   Room 2   Saturday 2021-08-21  14:00:00     2:00        $40.00
# 34   Room 2   Saturday 2021-08-28  14:00:00     2:00        $40.00
# 43   Room 2   Saturday 2021-09-04  14:00:00     2:00        $40.00
# 51   Room 2   Saturday 2021-09-11  14:00:00     2:00        $40.00
# 59   Room 2   Saturday 2021-09-18  14:00:00     2:00        $40.00
# 66   Room 2   Saturday 2021-09-25  14:00:00     2:00        $40.00
# 11   Room 3   Saturday 2021-08-07  14:00:00     2:00        $40.00
# 19   Room 3   Saturday 2021-08-14  14:00:00     2:00        $40.00
# 26   Room 3   Saturday 2021-08-21  14:00:00     2:00        $40.00
# 35   Room 3   Saturday 2021-08-28  14:00:00     2:00        $40.00
# 42   Room 3   Saturday 2021-09-04  14:00:00     2:00        $40.00
# 50   Room 3   Saturday 2021-09-11  14:00:00     2:00        $40.00
# 58   Room 3   Saturday 2021-09-18  14:00:00     2:00        $40.00
# 65   Room 3   Saturday 2021-09-25  14:00:00     2:00        $40.00
# 16   Room 2   Thursday 2021-08-12  17:30:00     2:00        $40.00
# 23   Room 2   Thursday 2021-08-19  17:30:00     2:00        $40.00
# 31   Room 2   Thursday 2021-08-26  17:30:00     2:00        $40.00
# 39   Room 2   Thursday 2021-09-02  17:30:00     2:00        $40.00
# 47   Room 2   Thursday 2021-09-09  17:30:00     2:00        $40.00
# 55   Room 2   Thursday 2021-09-16  17:30:00     2:00        $40.00
# 62   Room 2   Thursday 2021-09-23  17:30:00     2:00        $40.00
# 67   Room 2   Thursday 2021-09-30  17:30:00     2:00        $40.00
# 1    Room 2  Wednesday 2021-07-14  17:30:00     2:00        $40.00
# 4    Room 2  Wednesday 2021-07-21  17:30:00     2:00        $40.00
# 8    Room 2  Wednesday 2021-08-04  17:30:00     2:00        $40.00
# 14   Room 2  Wednesday 2021-08-11  17:30:00     2:00        $40.00
# 22   Room 2  Wednesday 2021-08-18  17:30:00     2:00        $40.00
# 30   Room 2  Wednesday 2021-08-25  17:30:00     2:00        $40.00
# 38   Room 2  Wednesday 2021-09-01  17:30:00     2:00        $40.00
# 46   Room 2  Wednesday 2021-09-08  17:30:00     2:00        $40.00
# 54   Room 2  Wednesday 2021-09-15  17:30:00     2:00        $40.00
# 61   Room 2  Wednesday 2021-09-22  17:30:00     2:00        $40.00
# 7    Room 3  Wednesday 2021-08-04  17:30:00     2:00        $40.00
# 15   Room 3  Wednesday 2021-08-11  17:30:00     2:00        $40.00
# 21   Room 3  Wednesday 2021-08-18  17:30:00     2:00        $40.00
# 29   Room 3  Wednesday 2021-08-25  17:30:00     2:00        $40.00
# 37   Room 3  Wednesday 2021-09-01  17:30:00     2:00        $40.00
# 45   Room 3  Wednesday 2021-09-08  17:30:00     2:00        $40.00
# 53   Room 3  Wednesday 2021-09-15  17:30:00     2:00        $40.00
# 60   Room 3  Wednesday 2021-09-22  17:30:00     2:00        $40.00

# %%
df.to_csv('hurrah.csv',index=False)
