# %%
import pandas as pd
from pathlib import Path

# %%
input_file = Path.cwd()/'course_history.csv'

# %%
df = pd.read_csv(input_file)

# %%
df
# Out:
#                                      Name  Code       Facilitator  \
# 0            A Social History of Cycling    T25        Alan Naber
# 1     Australian Film Club - Mystery Road  CA28  Danielle Desvaux
# 2                              Book Club    CA1      Diane Bailey
# 3                   Botanical Ink Drawing  AC56     Tania Daymond
# 4                   Craft and Coffee Club  CA18      Self Managed
# ..                                    ...   ...               ...
# 67     Watercolours Beginners and Ongoing  AC13    Verena Marmion
# 68  Writing your Memoirs Workshop Part 2    T22               NaN
# 69  Writing your Memoirs Workshop Part 2    T22               NaN
# 70                     Yoga for Everybody  HW14         Andi Bach
# 71                                    NaN   NaN               NaN
#
#         Session     Time   Weeks Run Time  Min Quota  Quota  Students  \
# 0   24-May-2021   3:30pm       1     1:00        7.0     14         3
# 1    7-Jul-2021   3:00pm       1     2:00        5.0     25         0
# 2   21-May-2021   9:30am       2     0:36        0.0     15         7
# 3    3-May-2021   9:30am       8    16:00        6.0     12        10
# 4   13-May-2021   1:00pm       8    16:00        2.0      8         3
# ..          ...      ...     ...      ...        ...    ...       ...
# 67  10-May-2021  12:00pm       8    16:00        5.0     10        10
# 68  21-Jun-2021   2:30pm       1     2:00        5.0     10         0
# 69  28-Jun-2021   2:30pm       1     2:00        5.0     10         0
# 70  10-May-2021   5:00pm       8     8:00        5.0      6         6
# 71          NaN      438  850:21      752        NaN    482       461
#
#     Members  Non-members     Waiting Operating Cost
# 0         3            0           1        $100.00
# 1         0            0           0          $0.00
# 2         7            0           0          $0.00
# 3        10            0           0        $800.00
# 4         2            1           0          $0.00
# ..      ...          ...         ...            ...
# 67       10            0           0        $560.00
# 68        0            0           0        $100.00
# 69        0            0           0        $100.00
# 70        5            1           0        $400.00
# 71       21           14  $28,377.00            NaN
#
# [72 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Code', 'Facilitator', 'Session', 'Time', 'Weeks', 'Run Time',
#        'Min Quota', 'Quota', 'Students', 'Members', 'Non-members', 'Waiting',
#        'Operating Cost'],
#       dtype='object')

# %%
df.drop(['Facilitator', 'Session', 'Time', 'Weeks', 'Run Time',
       'Min Quota', 'Quota', 'Students', 'Members', 'Non-members', 'Waiting',
       'Operating Cost'], axis=1, inplace=True)

# %%
df
# Out:
#                                      Name  Code
# 0            A Social History of Cycling    T25
# 1     Australian Film Club - Mystery Road  CA28
# 2                              Book Club    CA1
# 3                   Botanical Ink Drawing  AC56
# 4                   Craft and Coffee Club  CA18
# ..                                    ...   ...
# 67     Watercolours Beginners and Ongoing  AC13
# 68  Writing your Memoirs Workshop Part 2    T22
# 69  Writing your Memoirs Workshop Part 2    T22
# 70                     Yoga for Everybody  HW14
# 71                                    NaN   NaN
#
# [72 rows x 2 columns]

# %%
df.to_csv('hurrah.tab',index=False, sep='\t')

# %%
html = df.to_html(index=False)
text_file = open("index.html", "w")
text_file.write(html)
text_file.close()
