# %%
import pandas as pd
from pathlib import Path

# %%
input_file = Path.cwd()/'course_history.csv'

# %%
df = pd.read_csv(input_file)

# %%
df
# Out:
#                                                 Name  Code     Facilitator  \
# 0                               Bonsai for Beginners   GD3   Alicia Zablah
# 1                               Bonsai for Beginners   GD3   Alicia Zablah
# 2                                         Book Club    CA1    Diane Bailey
# 3                  Botanical Ink Drawing - Beginners  AC62   Tania Daymond
# 4                    Botanical Ink Drawing - Ongoing  AC56   Tania Daymond
# ..                                               ...   ...             ...
# 73                Watercolours Beginners and Ongoing  AC13  Verena Marmion
# 74                               Yoga for Everybody   HW14       Andi Bach
# 75  Your Favourite Photos in One Place, One Tap Away   CT7     Pete Chuang
# 76  Your Favourite Photos in One Place, One Tap Away   CT7     Pete Chuang
# 77                                               NaN   NaN             NaN
#
#         Session     Time   Weeks Run Time  Min Quota  Quota  Students  \
# 0   18-Aug-2021   2:00pm       4     8:00        4.0      4         0
# 1   22-Sep-2021   3:00pm       1     8:00        4.0      4         0
# 2   27-Aug-2021   9:30am       2     0:45        0.0     15         8
# 3   27-Jul-2021  12:45pm       8    16:00        6.0      9         4
# 4   26-Jul-2021   9:30am       8    16:00        6.0     12         5
# ..          ...      ...     ...      ...        ...    ...       ...
# 73  26-Jul-2021  12:00pm       8    16:00        5.0      9         7
# 74  26-Jul-2021   5:00pm       8     8:00        5.0      6         1
# 75  22-Jul-2021   1:00pm       1     1:00        1.0      6         6
# 76  29-Jul-2021   1:00pm       1     1:00        1.0      6         6
# 77          NaN      457  951:45      778        NaN    343       314
#
#     Members  Non-members     Waiting Operating Cost
# 0         0            0           0        $240.00
# 1         0            0           0        $240.00
# 2         8            0           0          $0.00
# 3         4            0           0        $800.00
# 4         5            0           0        $800.00
# ..      ...          ...         ...            ...
# 73        7            0           0        $560.00
# 74        1            0           0        $400.00
# 75        6            0           0          $0.00
# 76        6            0           0          $0.00
# 77       29            3  $32,735.00            NaN
#
# [78 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Code', 'Facilitator', 'Session', 'Time', 'Weeks', 'Run Time',
#        'Min Quota', 'Quota', 'Students', 'Members', 'Non-members', 'Waiting',
#        'Operating Cost'],
#       dtype='object')

# %%
df.drop(['Facilitator', 'Session', 'Time', 'Weeks', 'Run Time',
       'Min Quota', 'Quota', 'Students', 'Members', 'Non-members', 'Waiting',
       'Operating Cost'], axis=1, inplace=True)

# %%
df
# Out:
#                                                 Name  Code
# 0                               Bonsai for Beginners   GD3
# 1                               Bonsai for Beginners   GD3
# 2                                         Book Club    CA1
# 3                  Botanical Ink Drawing - Beginners  AC62
# 4                    Botanical Ink Drawing - Ongoing  AC56
# ..                                               ...   ...
# 73                Watercolours Beginners and Ongoing  AC13
# 74                               Yoga for Everybody   HW14
# 75  Your Favourite Photos in One Place, One Tap Away   CT7
# 76  Your Favourite Photos in One Place, One Tap Away   CT7
# 77                                               NaN   NaN
#
# [78 rows x 2 columns]

# %%
df.to_csv('hurrah.tab',index=False, sep='\t')

# %%
html = df.to_html(index=False)
text_file = open("index.html", "w")
text_file.write(html)
text_file.close()
