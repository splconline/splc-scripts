# %%
import pandas as pd
import numpy
from pathlib import Path
input_file = Path.cwd()/'blah.csv'
df = pd.read_csv(input_file)

# %%
df.head()
# Out:
#   Pers_num    Mem_Num Title     Given   Surname                Street  \
# 0     2685  201907010   NaN      Alan   Abraham                   NaN
# 1     3186  202103001    Mr     Brian     Adams       19 Karoo Street
# 2     3043  202010016   NaN   Maryon   Allbrook  48b Griffin Crescent
# 3     2997  202009002   NaN  Shirlene     Allen                   NaN
# 4     2873  202002055   Mrs     Susan     Allen      12 Alston Avenue
#
#         Suburb State PostC                       Email       Phone  \
# 0  South Perth    WA  6151     alanabraham54@gmail.com         NaN
# 1  South perth    WA  6151  brianjohnadams50@gmail.com  0400039718
# 2      Manning    WA  6152    brookwood@westnet.con.au   083132879
# 3  South Perth    WA   NaN    shirleneallen8@gmail.com         NaN
# 4         Como    WA  6152      skaprivate@bigpond.com  0408532811
#
#         Mobile                                             Status Mailouts  \
# ...

# %%
unique_emails = df.Email.unique()

# %%
unique_emails
# Out:
# array(['alanabraham54@gmail.com', 'brianjohnadams50@gmail.com',
#        'brookwood@westnet.con.au', 'shirleneallen8@gmail.com',
#        'skaprivate@bigpond.com', 'alisonandian01@hotmail.com',
#        'g_remigio7@bigpond.com', 'wandersen@iinet.net.au',
#        'karenanderson@iinet.net.au', 'ang_woi_lin@hotmail.com',
#        'rbamca@optusnet.com.au', 'neggie@iprimus.com.au',
#        'peteranstis@bigpond.com', 'calanon16@gmail.com',
#        'Marilyn_46@iinet.net.au', 'mnicolay@westnet.com.au',
#        'maggie.armstrong@iinet.net.au', 'bmarnold@iinet.net.au',
#        'Ashburns@ozemail.com.au', 'cashford25@hotmail.com',
#        'jeanetteashford@hotmail.com', 'becky8@live.com.au',
#        'andyavery56@yahoo.com', 'valav@bigpond.com.au',
#        'dibailey@iinet.net.au', 'ushika@ozemail.com.au',
#        'j.m.bain@bigpond.com', 'carol.baldini@health.wa.gov.au',
#        'arnold_baldwin@hotmail.com', 'baldwinc@live.com',
# ...

# %%
numpy.savetxt("hurrah.csv", unique_emails, delimiter=",", fmt="%s")
