# %%
import pandas as pd
import openpyxl
from pathlib import Path
input_file = Path.cwd()/'beconnected.xlsx'
df = pd.read_excel(input_file,engine='openpyxl')
df.head()
# Out:
#                 Timestamp Date of Session First Name   Surname  \
# 0 2021-07-20 09:57:38.204      2021-06-25     Lorna    Carroll
# 1 2021-07-20 10:07:35.365      2021-06-25    Pauline    Fraser
# 2 2021-07-20 10:14:21.523      2021-06-22       Mary    Moffet
# 3 2021-07-20 10:19:53.246      2021-06-22      Chris   Holland
# 4 2021-07-20 10:26:23.509      2021-07-05      Sandy  Crompton
#
#          Date of Birth       Suburb  Postcode  Gender  Country of Birth  \
# 0  1940-11-18 00:00:00      Manning    6152.0  Female         Australia
# 1  1942-04-30 00:00:00  South Perth    6151.0  Female  Northern Ireland
# 2  1943-03-10 00:00:00   Kensington    6151.0  Female           England
# 3  1953-12-25 00:00:00    Rivervale    6103.0    Male           England
# 4  1949-06-30 00:00:00         Como    6152.0  Female         Australia
#
#   Language Spoken at Home Aboriginal/Torres Islander Disability  \
# 0                 English                         No         No
# ...

# %%
dfg = df.groupby(['Surname','First Name']).count()

# %%
dfg.head()
# Out:
#                      Timestamp  Date of Session  Date of Birth  Suburb  \
# Surname  First Name
# Allbrook Maryon              3                3              2       2
# Ambra    Marra               1                1              1       1
# Anderson Karen               2                2              2       2
# Ang      Lin                 2                2              2       1
# Anstis   Lisa                5                5              4       4
#
#                      Postcode  Gender  Country of Birth  \
# Surname  First Name
# Allbrook Maryon             2       1                 2
# Ambra    Marra              1       1                 1
# Anderson Karen              2       2                 2
# Ang      Lin                2       2                 1
# Anstis   Lisa               4       4                 4
#
#                      Language Spoken at Home  Aboriginal/Torres Islander  \
# Surname  First Name
# ...

# %%
dfg.to_csv('hurrah.csv')
