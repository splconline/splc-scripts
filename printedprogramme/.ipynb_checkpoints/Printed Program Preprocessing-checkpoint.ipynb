# %%
import pandas as pd
from pathlib import Path
input_file = Path.cwd()/'course_list.csv'
df = pd.read_csv(input_file)

# %%
df
# Out:
#                                                  Name  Code  \
# 0                                Crochet Intermediate   AC4
# 1                              Crochet Beginners Plus   AC5
# 2                                    Crochet Advanced   AC6
# 3                             Drawing For Non-Drawers   AC7
# 4                         Ikebana Japanese Floral Art  AC26
# ..                                                ...   ...
# 63  The Inquisitive Traveller - Russia  from Rurik...  T31d
# 64  The Inquisitive Traveller - Festivals & Religi...  T31e
# 65  The Inquisitive Traveller - Uniquely Remarkabl...  T31f
# 66  The Inquisitive Traveller - Irkutsk in Siberia...  T31g
# 67                   Floating on the Canals of Europe   T32
#
#                                                 Times  Sessions Membership  \
# 0   (Monday 2-May-2022, 9:00am for 1:45hrs, runs f...        16   required
# 1   (Wednesday 4-May-2022, 3:30pm for 1:45hrs, run...         8   required
# ...

# %%
df["Times"]=df["Times"].str.replace("\)","")
df["Times"]=df["Times"].str.replace("\(","")
# Out:
# <ipython-input-16-0a5c0ec63571>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Times"]=df["Times"].str.replace("\)","")
# <ipython-input-16-0a5c0ec63571>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Times"]=df["Times"].str.replace("\(","")

# %%
df
# Out:
#                                                  Name  Code  \
# 0                                Crochet Intermediate   AC4
# 1                              Crochet Beginners Plus   AC5
# 2                                    Crochet Advanced   AC6
# 3                             Drawing For Non-Drawers   AC7
# 4                         Ikebana Japanese Floral Art  AC26
# ..                                                ...   ...
# 63  The Inquisitive Traveller - Russia  from Rurik...  T31d
# 64  The Inquisitive Traveller - Festivals & Religi...  T31e
# 65  The Inquisitive Traveller - Uniquely Remarkabl...  T31f
# 66  The Inquisitive Traveller - Irkutsk in Siberia...  T31g
# 67                   Floating on the Canals of Europe   T32
#
#                                                 Times  Sessions Membership  \
# 0   Monday 2-May-2022, 9:00am for 1:45hrs, runs fo...        16   required
# 1   Wednesday 4-May-2022, 3:30pm for 1:45hrs, runs...         8   required
# ...

# %%
df.to_csv('hurrah.csv',index=False)
