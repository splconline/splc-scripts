# %%
import pandas as pd
from pathlib import Path

# %%
input_file = Path.cwd()/'data'/'raw'/'course_income.csv'

# %%
df = pd.read_csv(input_file)

# %%
df
# Out:
#                                 Course  Code        First Session  Day  \
# 0       Acrylics For Beginners Ongoing   AC2    9-Feb-2021 9:30am  Tue
# 1            Autumn Afternoon Delight    OT2  26-Mar-2021 10:00am  Fri
# 2                 Birds of South Perth    T9   18-Feb-2021 1:00pm  Thu
# 3         Bonsai Bonanza for Beginners   GD3    9-Feb-2021 7:00pm  Tue
# 4                           Book Club    CA1   26-Feb-2021 9:30am  Fri
# ..                                 ...   ...                  ...  ...
# 84  Watercolours Beginners and Ongoing  AC13   8-Feb-2021 12:00pm  Mon
# 85      Writing Your Memoirs Workshops   T22  12-Apr-2021 10:00am  Mon
# 86      Writing Your Memoirs Workshops   T22  19-Apr-2021 10:00am  Mon
# 87                  Yoga for Everybody  HW14   15-Feb-2021 5:00pm  Mon
# 88                                 NaN   NaN                  NaN  NaN
#
#       Start  Sessions  Tot-Stus Concession-Stus   CM Fee Operating Fee  \
# 0    9:30am         8         4               0   $14.40       $720.00
# 1   10:00am         1        12               3    $4.90       $840.00
# 2    1:00pm         1        14               0    $5.30        $50.00
# 3    7:00pm         4         4               0    $7.20       $240.00
# 4    9:30am         2        12               4    $9.80         $0.00
# ..      ...       ...       ...             ...      ...           ...
# 84  12:00pm         8         9               1   $32.40       $560.00
# 85  10:00am         1         8               0    $3.60       $100.00
# 86  10:00am         1        10               0    $4.50       $100.00
# 87   5:00pm         8         6               0   $21.60       $320.00
# 88      477       639        86       $1,468.90  32146.5         $0.00
#
#    Concession Fee   Materials Total Income
# 0           $0.00         NaN      $593.75
# 1           $0.00         NaN      $990.00
# 2           $0.00         NaN      $205.00
# 3           $0.00         NaN      $400.00
# 4           $0.00         NaN      $240.00
# ..            ...         ...          ...
# 84          $0.00         NaN    $1,275.00
# 85          $0.00         NaN      $480.00
# 86          $0.00         NaN      $600.00
# 87          $0.00         NaN      $660.00
# 88          $0.00  $60,217.97          NaN
#
# [89 rows x 13 columns]

# %% [markdown]
# ## Lose the unwanted columns

# %%
df.drop(['Day','Start','Concession-Stus','CM Fee','Concession Fee', 'Materials'], axis=1, inplace=True)

# %% [markdown]
# ## Remove the dollar sign and comma from e.g. $1,500

# %%
df['Total Income']=df['Total Income'].str.lstrip('$')
df['Operating Fee']=df['Operating Fee'].str.lstrip('$')
df['Total Income']=df['Total Income'].str.replace(',','')
df['Operating Fee']=df['Operating Fee'].str.replace(',','')

# %% [markdown]
# ## Change the strings to numeric

# %%
df['Total Income']=df['Total Income'].str.lstrip('$')
df['Operating Fee']=df['Operating Fee'].str.lstrip('$')
df['Total Income']=df['Total Income'].str.replace(',','')
df['Operating Fee']=df['Operating Fee'].str.replace(',','')
df['Total Income']=pd.to_numeric(df['Total Income'])
df['Operating Fee']=pd.to_numeric(df['Operating Fee'])

# %% [markdown]
# ## Calculate and add the Profit column

# %%
df['Profit']=df['Total Income']-df['Operating Fee']

# %% [markdown]
# ## Sort by Profit

# %%
df = df.sort_values('Profit', ascending=False)

# %%
df
# Out:
#                                       Course  Code        First Session  \
# 54           Mahjong For Beginners - Chinese  CA22   20-Feb-2021 9:30am
# 6     Botanical Ink Drawing One Day Workshop  AC58   12-Apr-2021 9:30am
# 53          Mahjong Club Wednesday - Western  CA15   17-Feb-2021 9:30am
# 20                     Drawing - Portraiture  AC35   18-Feb-2021 1:00pm
# 60                     Ocean Moods in Pastel  AC33   26-Mar-2021 9:00am
# ..                                       ...   ...                  ...
# 67                     Shorelines in Pastels  AC34  23-Apr-2021 12:15pm
# 0             Acrylics For Beginners Ongoing   AC2    9-Feb-2021 9:30am
# 8                      Botanical Ink Drawing  AC56   18-Feb-2021 6:00pm
# 10  Colour Therapy Workshop: Part 1 (Friday)  HW15   19-Feb-2021 3:00pm
# 88                                       NaN   NaN                  NaN
#
#     Sessions  Tot-Stus  Operating Fee  Total Income   Profit
# 54         8        18          480.0       2145.00  1665.00
# 6          1        11          300.0       1885.00  1585.00
# 53         8        21            0.0       1260.00  1260.00
# 20         8        11          640.0       1870.00  1230.00
# 60         1         6          100.0       1020.00   920.00
# ..       ...       ...            ...           ...      ...
# 67         1         9           90.0          0.00   -90.00
# 0          8         4          720.0        593.75  -126.25
# 8          4         6          400.0          0.00  -400.00
# 10         1         5          500.0          0.00  -500.00
# 88       639        86            0.0           NaN      NaN
#
# [89 rows x 8 columns]

# %%
df.to_csv('hurrah.csv',index=False)
