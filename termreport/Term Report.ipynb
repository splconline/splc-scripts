# %%
import pandas as pd
from pathlib import Path

# %%
input_file = Path.cwd()/'data'/'raw'/'course_income.csv'

# %%
df = pd.read_csv(input_file)

# %%
df
# Out:
#                                                Course  Code  \
# 0                                Bonsai for Beginners   GD3
# 1                                Bonsai for Beginners   GD3
# 2                                          Book Club    CA1
# 3                   Botanical Ink Drawing - Beginners  AC62
# 4                     Botanical Ink Drawing - Ongoing  AC56
# ..                                                ...   ...
# 79  Your Favourite Photos in One Place, One Tap Aw...   CT7
# 80  Your Favourite Photos in One Place, One Tap Aw...  CT11
# 81  Your Favourite Photos in One Place, One Tap Aw...  CT11
# 82        eBooks: 10,000 Library Books in Your Pocket   CT9
# 83                                                NaN   NaN
#
#           First Session  Day    Start  Sessions  Tot-Stus Concession-Stus  \
# 0    18-Aug-2021 2:00pm  Wed   2:00pm         4         0               0
# 1    22-Sep-2021 3:00pm  Wed   3:00pm         3         0               0
# 2    27-Aug-2021 9:30am  Fri   9:30am         2         9               3
# 3   27-Jul-2021 12:45pm  Tue  12:45pm         8         9               0
# 4    26-Jul-2021 9:30am  Mon   9:30am         8         5               0
# ..                  ...  ...      ...       ...       ...             ...
# 79   26-Aug-2021 1:00pm  Thu   1:00pm         1         1               0
# 80    2-Sep-2021 1:00pm  Thu   1:00pm         1         5               1
# 81    9-Sep-2021 1:00pm  Thu   1:00pm         1         3               1
# 82   11-Aug-2021 1:00pm  Wed   1:00pm         1         3               0
# 83                  NaN  NaN      437       526        68       $1,350.65
#
#     CM Fee Operating Fee Concession Fee   Materials Total Income
# 0    $0.00       $240.00          $0.00         NaN        $0.00
# 1    $0.00       $180.00          $0.00         NaN        $0.00
# 2    $8.10         $0.00          $0.00         NaN      $180.00
# 3   $32.40       $800.00          $0.00         NaN    $1,543.75
# 4   $18.00       $800.00          $0.00         NaN      $950.00
# ..     ...           ...            ...         ...          ...
# 79   $0.45         $0.00          $0.00         NaN        $0.00
# 80   $2.25         $0.00          $0.00         NaN        $0.00
# 81   $1.35         $0.00          $0.00         NaN        $0.00
# 82   $1.35         $0.00          $0.00         NaN        $0.00
# 83   29094         $0.00          $0.00  $50,521.04          NaN
#
# [84 rows x 13 columns]

# %% [markdown]
# ## Lose the unwanted columns

# %%
df.drop(['Day','Start','Concession-Stus','CM Fee','Concession Fee', 'Materials'], axis=1, inplace=True)

# %% [markdown]
# ## Remove the dollar sign and comma from e.g. $1,500

# %%
df['Total Income']=df['Total Income'].str.lstrip('$')
df['Operating Fee']=df['Operating Fee'].str.lstrip('$')
df['Total Income']=df['Total Income'].str.replace(',','')
df['Operating Fee']=df['Operating Fee'].str.replace(',','')

# %% [markdown]
# ## Change the strings to numeric

# %%
df['Total Income']=df['Total Income'].str.lstrip('$')
df['Operating Fee']=df['Operating Fee'].str.lstrip('$')
df['Total Income']=df['Total Income'].str.replace(',','')
df['Operating Fee']=df['Operating Fee'].str.replace(',','')
df['Total Income']=pd.to_numeric(df['Total Income'])
df['Operating Fee']=pd.to_numeric(df['Operating Fee'])

# %% [markdown]
# ## Calculate and add the Profit column

# %%
df['Profit']=df['Total Income']-df['Operating Fee']

# %% [markdown]
# ## Sort by Profit

# %%
df = df.sort_values('Profit', ascending=False)

# %%
df
# Out:
#                                     Course  Code        First Session  \
# 52       Mahjong Wednesday Club - Western   CA15   28-Jul-2021 9:30am
# 73      Watercolours Beginners and Ongoing  AC13  26-Jul-2021 12:00pm
# 63                    Spanish A1 Beginners   L28    5-Aug-2021 1:30pm
# 32  Highlights of French History - Part 3    T30   25-Aug-2021 1:00pm
# 48           Mahjong - Beginners - Chinese  CA22   31-Jul-2021 9:00am
# ..                                     ...   ...                  ...
# 1                     Bonsai for Beginners   GD3   22-Sep-2021 3:00pm
# 0                     Bonsai for Beginners   GD3   18-Aug-2021 2:00pm
# 55                      Noongar Arty Yarns   T11   27-Aug-2021 2:00pm
# 14                Drawing My Pet - My Hero  AC61   14-Sep-2021 9:30am
# 83                                     NaN   NaN                  NaN
#
#     Sessions  Tot-Stus  Operating Fee  Total Income  Profit
# 52         8        21            0.0        1260.0  1260.0
# 73         8         9          560.0        1520.0   960.0
# 63         8         9          560.0        1440.0   880.0
# 32         4        17          200.0        1030.0   830.0
# 48         8        12          560.0        1380.0   820.0
# ..       ...       ...            ...           ...     ...
# 1          3         0          180.0           0.0  -180.0
# 0          4         0          240.0           0.0  -240.0
# 55         1         0          300.0           0.0  -300.0
# 14         2         0          300.0           0.0  -300.0
# 83       526        68            0.0           NaN     NaN
#
# [84 rows x 8 columns]

# %%
df = df[["Course","Code","First Session","Sessions","Tot-Stus","Total Income","Operating Fee","Profit"]]

# %%
df
# Out:
#                                     Course  Code        First Session  \
# 52       Mahjong Wednesday Club - Western   CA15   28-Jul-2021 9:30am
# 73      Watercolours Beginners and Ongoing  AC13  26-Jul-2021 12:00pm
# 63                    Spanish A1 Beginners   L28    5-Aug-2021 1:30pm
# 32  Highlights of French History - Part 3    T30   25-Aug-2021 1:00pm
# 48           Mahjong - Beginners - Chinese  CA22   31-Jul-2021 9:00am
# ..                                     ...   ...                  ...
# 1                     Bonsai for Beginners   GD3   22-Sep-2021 3:00pm
# 0                     Bonsai for Beginners   GD3   18-Aug-2021 2:00pm
# 55                      Noongar Arty Yarns   T11   27-Aug-2021 2:00pm
# 14                Drawing My Pet - My Hero  AC61   14-Sep-2021 9:30am
# 83                                     NaN   NaN                  NaN
#
#     Sessions  Tot-Stus  Total Income  Operating Fee  Profit
# 52         8        21        1260.0            0.0  1260.0
# 73         8         9        1520.0          560.0   960.0
# 63         8         9        1440.0          560.0   880.0
# 32         4        17        1030.0          200.0   830.0
# 48         8        12        1380.0          560.0   820.0
# ..       ...       ...           ...            ...     ...
# 1          3         0           0.0          180.0  -180.0
# 0          4         0           0.0          240.0  -240.0
# 55         1         0           0.0          300.0  -300.0
# 14         2         0           0.0          300.0  -300.0
# 83       526        68           NaN            0.0     NaN
#
# [84 rows x 8 columns]

# %%
df.to_csv('hurrah.csv',index=False)
